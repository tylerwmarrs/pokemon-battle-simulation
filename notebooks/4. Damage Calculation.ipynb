# %% [markdown]
# # Damage Calculation
#
# The damage calculation is based on the following website:
# https://www.math.miami.edu/~jam/azure/compendium/battdam.htm
#
# This notebook is used to create formula for the calculation.

# %%
import numpy as np

# %%
def battle_damage(a, b, c, d, x, y, crit):
    """
    a = attacker's Level
    b = attacker's Attack or Special
    c = attack Power
    d = defender's Defense or Special
    x = same-Type attack bonus (1 or 1.5)
    y = Type modifiers (40, 20, 10, 5, 2.5, or 0)
    z = a random number between 217 and 255
    crit = true or false
    """
    z = np.random.choice(np.arange(217, 256))
    crit_mult = 2
    if crit:
        crit_mult = 4
    
    damage = np.floor(((((crit_mult * a) / 5) + 2) * b * c) / d)
    damage = np.floor(damage / 50) + 2
    damage = np.floor(damage * x)    
    damage = np.floor(damage * y)
    
    # This is how you could compute the minimum and maximum
    # damage that this ability will do. Only for reference.
    min_damage = np.floor((damage * 217) / 255)
    max_damage = np.floor((damage * 255) / 255)
    print(min_damage, max_damage)
    
    return np.floor((damage * z) / 255)

# %%
battle_damage(100, 50, 75, 50, 1, 0.5, True)
# Out:
# 52.0 62.0
# 55.0

# %%
import pandas as pd

# %%
stats_df = pd.read_csv('../data/processed/pokemon_stats.csv')

# %%
stats_df.head()
# Out:
#    attack  defense  hp    pokemon  special-attack  special-defense  speed  \
# 0      90       55  52  farfetchd              58               62     60
# 1      85       95  80    rhyhorn              30               30     25
# 2      95       80  60   parasect              60               80     30
# 3      55      115  65    tangela             100               40     60
# 4      20       15  25       abra             105               55     90
#
#            types
# 0  flying,normal
# 1    rock,ground
# 2      grass,bug
# 3          grass
# 4        psychic

# %%
stats_df[(stats_df['speed'] > 100)]
# Out:
#      attack  defense   hp     pokemon  special-attack  special-defense  speed  \
# 6       110       80   70     scyther              55               80    105
# 8        80       75   83     pidgeot              70               70    101
# 25       50       70   60   electrode              80               80    150
# 50       83       57   65  electabuzz              95               85    105
# 52       65       60   65     jolteon             110               95    130
# 53       65       60   60      gengar             130               75    110
# 66      110       90  106      mewtwo             154               90    130
# 78      100       70   65    rapidash              80               80    105
# 89       50       45   55    alakazam             135               95    120
# 94      110       70   60      dodrio              60               60    110
# 105      70       60   65     persian              65               65    115
# 125     100       50   35     dugtrio              50               70    120
# 132     100       95   75      tauros              40               70    110
# 135      35       30   40     kadabra             120               70    105
# 140      90       55   60      raichu              90               80    110
# 148     105       65   80  aerodactyl              60               75    130
# 149      75       85   60     starmie             100               85    115
#
#              types
# 6       flying,bug
# 8    flying,normal
# 25        electric
# 50        electric
# 52        electric
# 53    poison,ghost
# 66         psychic
# 78            fire
# 89         psychic
# 94   flying,normal
# 105         normal
# 125         ground
# 132         normal
# 135        psychic
# 140       electric
# 148    flying,rock
# 149  psychic,water

# %%
stats_df[stats_df['pokemon'] == 'primeape']
# Out:
#     attack  defense  hp   pokemon  special-attack  special-defense  speed  \
# 76     105       60  65  primeape              60               70     95
#
#        types
# 76  fighting

# %%
moves_df = pd.read_csv('../data/processed/pokemon_moves_detailed.csv')

# %%
moves_df[moves_df['move_name'].str.contains('chop')]
# Out:
#         move_name                           move_url   pokemon  move_accuracy  \
# 1046  karate-chop  https://pokeapi.co/api/v2/move/2/  primeape          100.0
# 1047  karate-chop  https://pokeapi.co/api/v2/move/2/  primeape          100.0
# 1048  karate-chop  https://pokeapi.co/api/v2/move/2/    mankey          100.0
# 1049  karate-chop  https://pokeapi.co/api/v2/move/2/   machoke          100.0
# 1050  karate-chop  https://pokeapi.co/api/v2/move/2/    machop          100.0
# 1051  karate-chop  https://pokeapi.co/api/v2/move/2/   machamp          100.0
#
#      move_category  move_crit_rate move_damage_class  move_drain  \
# 1046        damage               1          physical           0
# 1047        damage               1          physical           0
# 1048        damage               1          physical           0
# 1049        damage               1          physical           0
# 1050        damage               1          physical           0
# 1051        damage               1          physical           0
#
#                                             move_effect  move_effect_chance  \
# 1046  Inflicts regular damage.  User's critical hit ...                 NaN
# 1047  Inflicts regular damage.  User's critical hit ...                 NaN
# 1048  Inflicts regular damage.  User's critical hit ...                 NaN
# 1049  Inflicts regular damage.  User's critical hit ...                 NaN
# 1050  Inflicts regular damage.  User's critical hit ...                 NaN
# 1051  Inflicts regular damage.  User's critical hit ...                 NaN
#
#       ...  move_min_hits  move_min_turns  move_power  move_pp  move_priority  \
# 1046  ...            NaN             NaN        50.0       25              0
# 1047  ...            NaN             NaN        50.0       25              0
# 1048  ...            NaN             NaN        50.0       25              0
# 1049  ...            NaN             NaN        50.0       25              0
# 1050  ...            NaN             NaN        50.0       25              0
# 1051  ...            NaN             NaN        50.0       25              0
#
#       move_stat_chance  move_stat_change  move_stat_change_amount  \
# 1046                 0               NaN                      NaN
# 1047                 0               NaN                      NaN
# 1048                 0               NaN                      NaN
# 1049                 0               NaN                      NaN
# 1050                 0               NaN                      NaN
# 1051                 0               NaN                      NaN
#
#            move_target  move_type
# 1046  selected-pokemon   fighting
# 1047  selected-pokemon   fighting
# 1048  selected-pokemon   fighting
# 1049  selected-pokemon   fighting
# 1050  selected-pokemon   fighting
# 1051  selected-pokemon   fighting
#
# [6 rows x 24 columns]

# %%
len(moves_df)
# Out:
# 1090

# %%
moves_stats_df = pd.merge(moves_df, stats_df, on='pokemon', how='inner')

# %% [markdown]
# # Critical Chance
#
# Critical chance is composed of the Pokemon's base speed stat. Information for the formula is found here:
#
# https://bulbapedia.bulbagarden.net/wiki/Critical_hit#In_Generation_I
#
# and
#
# http://www.psypokes.com/lab/criticalhits.php

# %%
def is_critical_hit(b, r):
    """
    b = basespeed of pokemon
    r = the crit rate for the move 0 or 1
    
    TODO: amping abilities not applied - focus energy etc..
    this is bugged in Gen 1 - but we will just ignore it.
    """
    prob = b / 512
    
    # compute threshold for high crit ratio move
    if r == 1:
        prob = b / 64
    
    chance = np.random.rand()
    return chance <= prob

# %%
crit_stats = []

for idx, row in moves_stats_df[['pokemon', 'move_name', 'move_crit_rate', 'speed']].iterrows():
    crits = 0
    
    for _ in range(1000):
        if is_critical_hit(row['speed'], row['move_crit_rate']):
            crits += 1
    
    crit_stats.append({
        'pokemon': row['pokemon'],
        'move': row['move_name'],
        'move_crit_rate': row['move_crit_rate'],
        'speed': row['speed'],
        'crits': crits / 1000
    })

# %%
crit_stats_df = pd.DataFrame(crit_stats)

# %%
crit_stats_df['crits'].describe()
# Out:
# count    1090.000000
# mean        0.157461
# std         0.137965
# min         0.019000
# 25%         0.096000
# 50%         0.135000
# 75%         0.178750
# max         1.000000
# Name: crits, dtype: float64

# %%
crit_stats_df[crit_stats_df['crits'] == 1]
# Out:
#      crits         move  move_crit_rate     pokemon  speed
# 10     1.0        slash               1     scyther    105
# 15     1.0        slash               1      pinsir     85
# 75     1.0        slash               1   sandslash     65
# 95     1.0        slash               1     diglett     95
# 101    1.0        slash               1     dugtrio    120
# 204    1.0        slash               1  charmeleon     80
# 214    1.0        slash               1   charizard    100
# 232    1.0        slash               1  charmander     65
# 269    1.0   crabhammer               1     kingler     75
# 278    1.0        slash               1    kabutops     80
# 317    1.0  karate-chop               1    primeape     95
# 318    1.0  karate-chop               1    primeape     95
# 325    1.0  karate-chop               1      mankey     70
# 377    1.0   sky-attack               1     moltres     90
# 504    1.0        slash               1     persian    115
# 513    1.0        slash               1      meowth     90
# 667    1.0   razor-leaf               1    venusaur     80
# 760    1.0   razor-leaf               1  victreebel     70

# %%
crit_stats_df[crit_stats_df['pokemon'] == 'persian']
# Out:
#      crits         move  move_crit_rate  pokemon  speed
# 504  1.000        slash               1  persian    115
# 505  0.225      scratch               0  persian    115
# 506  0.221        growl               0  persian    115
# 507  0.232      screech               0  persian    115
# 508  0.222      screech               0  persian    115
# 509  0.221         bite               0  persian    115
# 510  0.235         bite               0  persian    115
# 511  0.217  fury-swipes               0  persian    115
# 512  0.211      pay-day               0  persian    115

# %% [markdown]
# # Type Modifiers
#
# Chart is from:
#
# https://www.math.miami.edu/~jam/azure/compendium/typechart.htm

# %%
tables = pd.read_html('https://www.math.miami.edu/~jam/azure/compendium/typechart.htm')

# %%
tables[3]
# Out:
#                    0                  1                  2   \
# 0       Attack Type v  Defending Type(s)  Defending Type(s)
# 1       Attack Type v                Fir                Wat
# 2    Special attacks:   Special attacks:   Special attacks:
# 3                Fire                0.5                0.5
# 4               Water                  2                0.5
# 5               Grass                0.5                  2
# 6            Electric                  1                  2
# 7                 Ice                  1                0.5
# 8             Psychic                  1                  1
# 9   Physical attacks:  Physical attacks:  Physical attacks:
# 10             Normal                  1                  1
# 11           Fighting                  1                  1
# 12             Flying                  1                  1
# 13             Ground                  2                  1
# 14               Rock                  2                  1
# 15                Bug                0.5                  1
# 16             Poison                  1                  1
# 17              Ghost                  1                  1
# 18             Dragon                  ?                  ?
#
#                    3                  4                  5   \
# 0   Defending Type(s)  Defending Type(s)  Defending Type(s)
# 1                 Gra                Ele                Ice
# 2    Special attacks:   Special attacks:   Special attacks:
# 3                   2                  1                  2
# 4                 0.5                  1                  1
# 5                 0.5                  1                  1
# 6                 0.5                0.5                  1
# 7                   2                  1                0.5
# 8                   1                  1                  1
# 9   Physical attacks:  Physical attacks:  Physical attacks:
# 10                  1                  1                  1
# 11                  1                  1                  2
# 12                  2                0.5                  1
# 13                0.5                  2                  1
# 14                  1                  1                  2
# 15                  2                  1                  1
# 16                  2                  1                  1
# 17                  1                  1                  1
# 18                  ?                  ?                  ?
#
#                    6                  7                  8   \
# 0   Defending Type(s)  Defending Type(s)  Defending Type(s)
# 1                 Psy                Nor                Fgt
# 2    Special attacks:   Special attacks:   Special attacks:
# 3                   1                  1                  1
# 4                   1                  1                  1
# 5                   1                  1                  1
# 6                   1                  1                  1
# 7                   1                  1                  1
# 8                 0.5                  1                  2
# 9   Physical attacks:  Physical attacks:  Physical attacks:
# 10                  1                  1                  1
# 11                0.5                  2                  1
# 12                  1                  1                  2
# 13                  1                  1                  1
# 14                  1                  1                0.5
# 15                  2                  1                0.5
# 16                  1                  1                  1
# 17                  0                  0                  1
# 18                  ?                  ?                  ?
#
#                    9                  10                 11  \
# 0   Defending Type(s)  Defending Type(s)  Defending Type(s)
# 1                 Fly                Gro                Rck
# 2    Special attacks:   Special attacks:   Special attacks:
# 3                   1                  1                0.5
# 4                   1                  2                  2
# 5                 0.5                  2                  2
# 6                   2                  0                  1
# 7                   2                  2                  1
# 8                   1                  1                  1
# 9   Physical attacks:  Physical attacks:  Physical attacks:
# 10                  1                  1                0.5
# 11                0.5                  1                  2
# 12                  1                  1                0.5
# 13                  0                  1                  2
# 14                  2                0.5                  1
# 15                0.5                  1                  1
# 16                  1                0.5                0.5
# 17                  1                  1                  1
# 18                  ?                  ?                  ?
#
#                    12                 13                 14                 15
# 0   Defending Type(s)  Defending Type(s)  Defending Type(s)  Defending Type(s)
# 1                 Bug                Poi                Gho                Drg
# 2    Special attacks:   Special attacks:   Special attacks:   Special attacks:
# 3                   2                  1                  1                0.5
# 4                   1                  1                  1                0.5
# 5                 0.5                0.5                  1                0.5
# 6                   1                  1                  1                0.5
# 7                   1                  1                  1                  2
# 8                   1                  2                  1                  1
# 9   Physical attacks:  Physical attacks:  Physical attacks:  Physical attacks:
# 10                  1                  1                  0                  1
# 11                0.5                0.5                  0                  1
# 12                  2                  1                  1                  1
# 13                0.5                  2                  1                  1
# 14                  2                  1                  1                  1
# 15                  1                  2                  1                  1
# 16                  2                0.5                0.5                  1
# 17                  1                  1                  2                  1
# 18                  ?                  ?                  ?                  ?

# %%
special_attacks_df = tables[3].iloc[3:9]

# %%
defenders = ['Fire', 'Water', 'Grass', 'Electric', 'Ice', 'Psychic', 'Normal', 'Fighting', 'Flying', 'Ground', 'Rock', 'Bug', 'Poison', 'Ghost', 'Dragon']

# %%
attackers = special_attacks_df[0]

# %%
special_attacks_df = pd.DataFrame(special_attacks_df.values[:, 1:], columns=defenders)

# %%
special_attacks_df['attack_type'] = attackers.values

# %%
special_attacks_df = special_attacks_df.set_index('attack_type')

# %%
special_attacks_df
# Out:
#             Fire Water Grass Electric  Ice Psychic Normal Fighting Flying  \
# attack_type
# Fire         0.5   0.5     2        1    2       1      1        1      1
# Water          2   0.5   0.5        1    1       1      1        1      1
# Grass        0.5     2   0.5        1    1       1      1        1    0.5
# Electric       1     2   0.5      0.5    1       1      1        1      2
# Ice            1   0.5     2        1  0.5       1      1        1      2
# Psychic        1     1     1        1    1     0.5      1        2      1
#
#             Ground Rock  Bug Poison Ghost Dragon
# attack_type
# Fire             1  0.5    2      1     1    0.5
# Water            2    2    1      1     1    0.5
# Grass            2    2  0.5    0.5     1    0.5
# Electric         0    1    1      1     1    0.5
# Ice              2    1    1      1     1      2
# Psychic          1    1    1      2     1      1

# %%
special_attacks_df.to_csv('../data/processed/type_modifiers_special.csv')

# %%
physical_attacks_df = tables[3].iloc[10:18]

# %%
rename_to = {}

for i, val in zip(np.arange(16), ['attack_type',] + defenders):
    rename_to[i] = val

# %%
physical_attacks_df = physical_attacks_df.rename(columns=rename_to).set_index('attack_type')

# %%
physical_attacks_df
# Out:
#             Fire Water Grass Electric Ice Psychic Normal Fighting Flying  \
# attack_type
# Normal         1     1     1        1   1       1      1        1      1
# Fighting       1     1     1        1   2     0.5      2        1    0.5
# Flying         1     1     2      0.5   1       1      1        2      1
# Ground         2     1   0.5        2   1       1      1        1      0
# Rock           2     1     1        1   2       1      1      0.5      2
# Bug          0.5     1     2        1   1       2      1      0.5    0.5
# Poison         1     1     2        1   1       1      1        1      1
# Ghost          1     1     1        1   1       0      0        1      1
#
#             Ground Rock  Bug Poison Ghost Dragon
# attack_type
# Normal           1  0.5    1      1     0      1
# Fighting         1    2  0.5    0.5     0      1
# Flying           1  0.5    2      1     1      1
# Ground           1    2  0.5      2     1      1
# Rock           0.5    1    2      1     1      1
# Bug              1    1    1      2     1      1
# Poison         0.5  0.5    2    0.5   0.5      1
# Ghost            1    1    1      1     2      1

# %%
physical_attacks_df.to_csv('../data/processed/type_modifiers_physical.csv')

# %%
pd.concat([physical_attacks_df, special_attacks_df]).to_csv('../data/processed/type_modifiers.csv')
